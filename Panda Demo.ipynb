# %%
import pandas as pd

# %%
df = pd.read_csv("survey_results_public.csv", index_col="Respondent") # sets Index to Responded column 
schema_df = pd.read_csv("survey_results_schema.csv", index_col="Column") # sets index to Column

# %%
pd.set_option("display.max_columns", 85)
pd.set_option("display.max_rows", 85)

# %%
df.head(3) #top 5 rows
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
# 3                             Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# ...

# %%
schema_df.tail(15) #last 15 rows
# Out:
#                                                     QuestionText
# Column
# SOAccount                  Do you have a Stack Overflow account?
# SOPartFreq     How frequently would you say you participate i...
# SOJobs         Have you ever used or visited Stack Overflow J...
# EntTeams       Have you ever used Stack Overflow for Enterpri...
# SOComm         Do you consider yourself a member of the Stack...
# WelcomeChange  Compared to last year, how welcome do you feel...
# SONewContent   Would you like to see any of the following on ...
# Age            What is your age (in years)? If you prefer not...
# Gender         Which of the following do you currently identi...
# Trans                            Do you identify as transgender?
# Sexuality      Which of the following do you currently identi...
# Ethnicity      Which of the following do you identify as? Ple...
# Dependents     Do you have any dependents (e.g., children, el...
# ...

# %%
df.shape #rows and columns
# Out:
# (88883, 84)

# %%
df["Hobbyist"] #shows head and tail
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df["Hobbyist"].value_counts() #shows yes and no anwser count
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
df.loc[[0,1,3], "Hobbyist"] #spesific rows and columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.loc[[0,1,3], "Hobbyist"] #spesific rows and columns
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1330, in _LocIndexer._getitem_tuple(self, tup)
#    1328 with suppress(IndexingError):
#    1329     tup = self._expand_ellipsis(tup)
# -> 1330     return self._getitem_lowerdim(tup)
#    1332 # no multi-index, so validate all of the indexers
# ...

# %%
df.loc[0:2, "Hobbyist"] #slicing rows

# %%
df.loc[0:2, "Hobbyist":"Employment"] #Slicing columns

# %%
schema_df

# %%
schema_df.loc["MgrIdiot", "QuestionText"]

# %%
schema_df.sort_index(ascending=True) #sorts indexes alphabelically but does not manipulate it. Unless adding (inplace=True)

# %%
high_salary = (df["ConvertedComp"] > 70000)

# %%
countries = ["United States", "India", "United Kindom", "Germany", "Canada"]
filt = df["Country"].isin(countries)

# %%
df.loc[high_salary, ["Country", "LanguageWorkedWith", "ConvertedComp"]] #Shows people with highSalary and what language they work with + the salary

# %%
df.loc[filt, "Country"]

# %%
df["LanguageWorkedWith"]

# %%
filt = df["LanguageWorkedWith"].str.contains("Python", na=False) #Check language column for all the ones that contain pyhton

# %%
df.loc[filt, "LanguageWorkedWith"]

# %%
df.rename(columns={"ConvertedComp": "SalaryUSD"}, inplace=True)

# %%
df["SalaryUSD"]
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
df["Hobbyist"]
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df["Hobbyist"].map({"Yes": True, "No": False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df["Hobbyist"] = df["Hobbyist"].map({"Yes": True, "No": False})

# %%
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# ...                                                       ...       ...
# 88377                                                     NaN      True
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
# 88863                                                     NaN      True
#
#                                                   OpenSourcer  \
# Respondent
# ...
